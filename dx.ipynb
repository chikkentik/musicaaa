# %%
import requests

url = "https://priaid-symptom-checker-v1.p.rapidapi.com/diagnosis"


querystring = {"symptoms":"[59]","gender":"male","year_of_birth":"1984","language":"en-gb"}

headers = {
    'x-rapidapi-host': "priaid-symptom-checker-v1.p.rapidapi.com",
    'x-rapidapi-key': "e9e82ff66bmsh2353f291af944f0p1f8063jsn60d6c57e9d77"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

import json
print (json.dumps(response.json(), indent=2))

#print(response.text)
# Out:
# [
#   {
#     "Issue": {
#       "ID": 99,
#       "Name": "Benign prostate enlargement",
#       "Accuracy": 90,
#       "Icd": "N40",
#       "IcdName": "Hyperplasia of prostate",
#       "ProfName": "Benign prostatic hyperplasia",
#       "Ranking": 1
#     },
#     "Specialisation": [
#       {
#         "ID": 15,
#         "Name": "General practice",
#         "SpecialistID": 3
#       },
#       {
#         "ID": 42,
#         "Name": "Urology",
#         "SpecialistID": 9
#       }
#     ]
#   },
#   {
#     "Issue": {
#       "ID": 17,
#       "Name": "Diabetes",
#       "Accuracy": 79.77273,
#       "Icd": "E10;E11;E12;E13;E14",
#       "IcdName": "Type 1 diabetes mellitus;Type 2 diabetes mellitus;Malnutrition-related diabetes mellitus;Other specified diabetes mellitus;Unspecified diabetes mellitus",
#       "ProfName": "Diabetes mellitus",
#       "Ranking": 2
#     },
#     "Specialisation": [
#       {
#         "ID": 12,
#         "Name": "Endocrinology",
# ...

# %%
print (type (response.json()))
print (len (response.json()))
print (response.json()[0]["Issue"]["Name"])
# Out:
# <class 'list'>
# 5
# Benign prostate enlargement

# %%
type(response.json())
# Out:
# list

# %%
x = len (response.json())
# print(x)
for n in range(x):
#     print(n)
    print (response.json()[n]["Issue"]["Name"])
# Out:
# Benign prostate enlargement
# Diabetes
# Urinary tract infection
# Involuntary urination
# Disorder causing imbalance of water in the body

# %%
x = len(response.json())
n = 0
while n<x:
    print (response.json()[n]["Issue"]["Name"])
    n+=1

# loop1: n=0 , x=5 , loop gets executed
# loop2: n=1 , x=5 , loop gets executed
# loop3: n=2 , x=5 , loop gets executed
# loop4: n=3 , x=5 , loop gets executed
# loop5: n=4 , x=5 , loop gets executed
# loop6: n=5 , x=5 , loop does NOT get executed
# Out:
# Benign prostate enlargement
# Diabetes
# Urinary tract infection
# Involuntary urination
# Disorder causing imbalance of water in the body

# %%
for i in response.json():
    print(i["Issue"]["Name"])
# Out:
# Benign prostate enlargement
# Diabetes
# Urinary tract infection
# Involuntary urination
# Disorder causing imbalance of water in the body

# %%
for i in response.json():
    print(i)
# Out:
# {'Issue': {'ID': 99, 'Name': 'Benign prostate enlargement', 'Accuracy': 90, 'Icd': 'N40', 'IcdName': 'Hyperplasia of prostate', 'ProfName': 'Benign prostatic hyperplasia', 'Ranking': 1}, 'Specialisation': [{'ID': 15, 'Name': 'General practice', 'SpecialistID': 3}, {'ID': 42, 'Name': 'Urology', 'SpecialistID': 9}]}
# {'Issue': {'ID': 17, 'Name': 'Diabetes', 'Accuracy': 79.77273, 'Icd': 'E10;E11;E12;E13;E14', 'IcdName': 'Type 1 diabetes mellitus;Type 2 diabetes mellitus;Malnutrition-related diabetes mellitus;Other specified diabetes mellitus;Unspecified diabetes mellitus', 'ProfName': 'Diabetes mellitus', 'Ranking': 2}, 'Specialisation': [{'ID': 12, 'Name': 'Endocrinology', 'SpecialistID': 26}, {'ID': 15, 'Name': 'General practice', 'SpecialistID': 3}, {'ID': 19, 'Name': 'Internal medicine', 'SpecialistID': 4}]}
# ...

# %%
for i in response.json():
    print(i['Issue']['ID'])
# Out:
# 99
# 17
# 59
# 411
# 482

# %%
response.json()[0]
# Out:
# {'Issue': {'ID': 99,
#   'Name': 'Benign prostate enlargement',
#   'Accuracy': 90,
#   'Icd': 'N40',
#   'IcdName': 'Hyperplasia of prostate',
#   'ProfName': 'Benign prostatic hyperplasia',
#   'Ranking': 1},
#  'Specialisation': [{'ID': 15, 'Name': 'General practice', 'SpecialistID': 3},
#   {'ID': 42, 'Name': 'Urology', 'SpecialistID': 9}]}

# %%
for i in [3,4,52,3,3,4]:
    print(i)
# Out:
# 3
# 4
# 52
# 3
# 3
# 4

# %%
x = len (response.json())

n = 0

while n range(x):
    print (response.json()[n]["Issue"]["Name"])
# Out:
# D
# i
# s
# o
# r
# d
# e
# r
#
# c
# a
# u
# s
# i
# n
# g
#
# i
# m
# b
# a
# l
# a
# n
# c
# e
#
# o
# f
#
# w
# a
# t
# e
# r
#
# i
# n
#
# t
# h
# e
#
# b
# o
# d
# y

# %%
Print (“number of items:”, len(listname))

For people in content[“people”]:
	Print(people[“name”])

# %%
import requests
import json

url = "https://priaid-symptom-checker-v1.p.rapidapi.com/symptoms"

querystring = {"format":"json","language":"en-gb"}

headers = {
    'x-rapidapi-host': "priaid-symptom-checker-v1.p.rapidapi.com",
    'x-rapidapi-key': "e9e82ff66bmsh2353f291af944f0p1f8063jsn60d6c57e9d77"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
print (json.dumps(response.json(), indent=2))
#print(response.text)
# Out:
# [
#   {
#     "ID": 188,
#     "Name": "Abdominal guarding"
#   },
#   {
#     "ID": 10,
#     "Name": "Abdominal pain"
#   },
#   {
#     "ID": 223,
#     "Name": "Abdominal pain associated with menstruation"
#   },
#   {
#     "ID": 984,
#     "Name": "Absence of a pulse"
#   },
#   {
#     "ID": 974,
#     "Name": "Aggressiveness"
#   },
#   {
#     "ID": 981,
#     "Name": "Agitation"
#   },
#   {
#     "ID": 996,
#     "Name": "Ankle deformity"
#   },
#   {
#     "ID": 147,
#     "Name": "Ankle swelling"
#   },
#   {
#     "ID": 238,
#     "Name": "Anxiety"
#   },
#   {
#     "ID": 971,
#     "Name": "Arm swelling"
#   },
#   {
#     "ID": 998,
#     "Name": "Back deformity"
#   },
#   {
#     "ID": 104,
#     "Name": "Back pain"
#   },
#   {
#     "ID": 180,
#     "Name": "Black stools"
#   },
#   {
#     "ID": 57,
#     "Name": "Blackening of vision"
#   },
#   {
#     "ID": 24,
#     "Name": "Blackhead"
#   },
#   {
#     "ID": 284,
#     "Name": "Bleeding from vagina"
# ...

# %%
# sx list
sx_list = response.json()

# passing through list with sx and code AND the sx name that you inputed
#for every item in sx_list 

def find_sxcode(sx_list,symp_name ):
    for sx  in sx_list:
        if sx ["Name"]==symp_name:
            print("Found code: ", sx["ID"])
            
find_sxcode(sx_list, "Abdominal pain")
# Out:
# Found code:  10

# %%
sx_list # is a list 
type (sx_list)
# Out:
# list

# %%
for i in sx_list:
    print (i ["Name"])
# Out:
# Abdominal guarding
# Abdominal pain
# Abdominal pain associated with menstruation
# Absence of a pulse
# Aggressiveness
# Agitation
# Ankle deformity
# Ankle swelling
# Anxiety
# Arm swelling
# Back deformity
# Back pain
# Black stools
# Blackening of vision
# Blackhead
# Bleeding from vagina
# Bleeding in the conjunctiva of the eye
# Bloated feeling in the stomach
# Blood in stool
# Bloody cough
# Blue colored skin
# Blue spot on skin
# Blurred vision
# Bold area among hair on the head
# Bone fracture
# Breathing-related pains
# Brittleness of nails
# Bulging abdominal wall
# Burning eyes
# Burning in the throat
# Burning nose
# Burning sensation when urinating
# Changes in the nails
# Cheek swelling
# Chest pain
# Chest tightness
# Chills
# Coarsening of the skin structure
# Cold feet
# Cold hands
# Cold sweats
# Cough
# Cough with sputum
# Cramps
# Cravings
# Crusting
# Curvature of the spine
# Dark urine
# Decreased urine stream
# Delayed start to urination
# Diarrhea
# ...

# %%
a = 7 
#a is a variable of type int
fat_house= house (3,4,5)
#fat_ house is an object/variable of type class house
